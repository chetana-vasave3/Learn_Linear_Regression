# %% [markdown]
# # seaborn

# %% [markdown]
# - Seaborn is a data visuliztion library in python
# - It helps to create interesting an interactive plots to draw meaningful information from  data.
# - Commonly used for DS and ML tasks.
# - Backbone of EDA(Exploratory Data Analysis)
# - The best use seaborn is that u will be able to get lot of statistical tools which will actually lep you  to understand  more about the data

# %% [markdown]
# - In datset you will be having Features like f1,f2,f3....
# - based on the classification and regression problem you will be dividing your dataset.
# - and this is with respect to supervised ML.
# - Initailly u have to divide this features into Independent and dependent variable.
# - If we have 2 features f1 and f2  we can draw 2D plot and by using this plot we will be able to find lot of info through this.
# - Suppose we have 1 feature then this is basically called as univariate analysis.
# - For 2 features this is called as bivariate analysis.
# - now if we want to findout the relationship bw this two features and
# - this kind of univariate and bivariate analysis can be easily done with seaborn.
# - It is also help us to analyze multiple features(multivariate analysis) in our DS.
# - So for that we are going to use various kind of plots.

# %% [markdown]
# - Distplot   = univariate
# - Joinplot   = bivariate analysis.
# - Paireplot = multivariate analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset('tips')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### to find I.V. and D.V.

# %% [markdown]
# - our main aim will be that  we have to findout the "tip" here.
# - we should be create a model wherin  we should be able to assume what tip  it will be based on the other feature
# - this is what is our problem statement
# - So here tip is ur actual dependent feature.
# - and total_bill,sex,smoker ,day,time and size this are Independent features.
# rD

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### correation with heatmap = to findout inter relationship bw all the features.

# %% [markdown]
# - We can find correlation only when ur values are either int or float points.
# - If ur values are categorical feature u will not be able to find out correlation.
# - Whenever we are tryinig to apply correlation ur value will be ranging from -1 to +1 and that is specifically called as Pearson coefficiant correlation.

# %% [markdown]
# - correlation heatmap uses colored cells
# - It is very imp in feature selection.

# %%
data.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# - here total_bill,tip  and size only this 3 columns have numerical data.
# - here we are getting positive correlation

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
a=pd.read_csv(r"C:\Users\DELL\Downloads\emp_data.csv")
a
# Out:
#      EmpID     FName     LName Gender                         EMail  Salary  \
# 0   677509      Lois    Walker      F       lois.walker@hotmail.com  168251
# 1   940761    Brenda  Robinson      F     brenda.robinson@gmail.com   51063
# 2   428945       Joe  Robinson      M        joe.robinson@gmail.com   50155
# 3   408351     Diane     Evans      F         diane.evans@yahoo.com  180294
# 4   193819  Benjamin   Russell      M  benjamin.russell@charter.net  117642
# ..     ...       ...       ...    ...                           ...     ...
# 95  639892      Jose      Hill      M         jose.hill@hotmail.com  129774
# 96  704709    Harold    Nelson      M       harold.nelson@gmail.com  156194
# 97  461593    Nicole      Ward      F         nicole.ward@yahoo.com   95673
# 98  392491   Theresa    Murphy      F      theresa.murphy@gmail.com   51015
# 99  495141     Tammy     Young      F       tammy.young@comcast.net   93650
#
#          LOC    MGR_ID  DEPT_ID
# ...

# %%
## hetamap of dataset having nanvalues

sns.heatmap(a.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Dist plot

# %% [markdown]
# - It helps u to create histograms
# - It represents the overall distribution of continuous data variables
# - Represents univariate distribution of data i>e data distribution of a variable agains the density distribution
# - Series, 1d-array, or list(only numeric values)

# %%
a=np.random.rand(100)
sns.distplot(a)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(data["tip"])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %% [markdown]
# ### join plot

# %% [markdown]
# - A join plot allows to study the relationship bw 2 numeric vaiables.
# - It is usually a scatterplot,a hexbin plot a 2D historam or a 2D density plot
# - used for bivariate anaysis

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.jointplot(x="tip",y="total_bill",data=data,kind="hex") 

## data=ur dataset  
## kind="hex"- hexagonal shape relation
## we can give kind="scatter" | "kde" | "hist" | "hex" | "reg" | "resid"

# %%
sns.jointplot(x="tip",y="total_bill",data=data,kind="reg")

# %%
sns.jointplot(x="tip",y="total_bill",data=data,kind="scatter",color="g")

# %%
sns.jointplot(x="tip",y="total_bill",data=data,kind="kde")

# %% [markdown]
# ### Pair Plot

# %% [markdown]
# - used for multi variate anaysis
# - A pair plot also known as scatterplot,in which one variable in the same data row is matched with another variable's value
# - showing all variables paired with all the other variables

# %%
sns.pairplot(data)

# %% [markdown]
# - using pairplot we can also findout relationship bw categorical data

# %%
sns.pairplot(data,hue="sex")

# %%
sns.pairplot(data,hue="smoker")

# %%
#here more no. of people are non smoker u can see
data["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# ### Categorical Plots

# %% [markdown]
# seaborn also helps us in doing analysis on Categorical Data point.

# %% [raw]
# - 1) boxplot
# - 2) barplot
# - 3) countplot

# %% [raw]
# In our exaple we have 4 categorical features sex,smoker,day and time

# %% [raw]
# 1) count plot

# %%
sns.countplot("sex",data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot("smoker",data=data)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot("time",data=data)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.countplot(y="day",data=data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='day'>

# %% [raw]
# 2) bar plot
#
# - In countplot u either have to give x value or y value
# - In bar plot u have to give both x and y value
# - There should'nt be both x and y are categorical.

# %%
sns.barplot(x="total_bill",y="sex",data=data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='sex'>

# %%
sns.barplot(x="time",y="tip",data=data)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %% [raw]
# 3) Box plot
# - This plot helps you to find out summary of the dataset values having proprties like min,max,1st quartile,median,third qurtile - circle in output represents outlires
# - In the box plot box is created from the 1st qurtile to the 3rd qurtile ,a vertical line is also there which goes through the box at the median
# - X axis denotes the data to be plotted while y axis denotes the data of frequency distribution

# %%
sns.boxplot(data=data,orient="v")

## orient : "v" | "h", optional
Orientation of the plot (vertical or horizontal)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="day",y="total_bill",data=data)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
